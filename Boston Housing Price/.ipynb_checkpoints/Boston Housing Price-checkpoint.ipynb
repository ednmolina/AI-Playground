# %% [markdown]
# # Load the Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import boston_housing
from keras import models, layers

# %%
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()

# %%
train_data.shape, test_data.shape
# Out:
# ((404, 13), (102, 13))

# %%
num_features = train_data.shape[1]

# %% [markdown]
# The targets are the median values of the owner-occupied homes, in thousands of dollars. The prices are between 10k to 50k.

# %% [markdown]
# # Data Prep
# Here we will normalize the dataset because it is problematics to feed intro a neural network values that take on wildly different range. The network might be able to adapt to wide ranged data but it would make learning much more difficult. Here we will subtract the each datapoint from the mean of the feature and divide by the standard deviation.

# %%
mean = train_data.mean(axis = 0)
std = train_data.std(axis = 0)

train_data -= mean
train_data /= std

test_data -= mean
test_data /= std

# %% [markdown]
# # Building the network
# We use a small network with two hidden layers each with 64 units. In general, the less training data, the worse overfitting will be, and using a small entwork is one way to mitigate overfitting.
#
# The network ends with a single unit and no activation (it will be a linear layer). This is a typical setup for scalar regression. A regression is where you're truing to predict a single continuous value.
#
# Applying an activation function would constrain the range of the outputs, the network would only be able to predict values between 0 and 1. Here because the last layer is purely linear, the network is free to learn values in any range.
#
# The network will be complied with the mse loss function whcih is the square of the difference between the predictions and the targets. Thi is a widely used loss function for regression problems.
#
# A new metric will also be monitoried during training, the mean squared error. It is the absolute value of the difference between the predictions and the targets. In this case, an MAE of .5 would mean the predictions are of by $500.

# %%
def build_model():
    model = models.Sequential()
    model.add(layers.Dense(64, activation='relu',
                            input_shape=(num_features,)))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    return model

# %% [markdown]
# # K-fold validation
# To evaluate the netwrok while the parameters are being adjusted, the data could be split into training and validation. However, with a small dataset the validation would be very small. As a result of this the validation scores might change a lot depending on which data points you chose to use for validation and which you chose for training. The validation scores might have a high variance with regard to the validation split. What this entails is that it would be difficult to reliably evaluate the model.
#
# The solution to this problem is to use K-fold validation whcih consists of splitting the available data into K partitions instantiating K identical models, and training each one on K-1 partitions while evaluating on the remaining partition. The validation score for the model is then the average of the various K validation scores obtained.

# %%
k = 4
num_val_samples = len(train_data)//k

num_epochs = 2
all_scores = []

num_val_samples
# Out:
# 101

# %%
for i in range(k):
    print ('processing fold #', i)
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]
    
    partial_train_data = np.concatenate( [train_data[:i * num_val_samples],
                                          train_data[(i + 1) * num_val_samples:]], axis=0)
    
    partial_train_targets = np.concatenate( [train_targets[:i * num_val_samples],
                                             train_targets[(i + 1) * num_val_samples:]], axis=0)
    
    model = build_model()
    
    model.fit(partial_train_data, partial_train_targets,
              epochs=num_epochs, batch_size=1, verbose=1)
    
    val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
    
    all_scores.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/2
# 303/303 [==============================] - 0s 1ms/step - loss: 171.5486 - mean_absolute_error: 9.5928
# Epoch 2/2
# 303/303 [==============================] - 0s 807us/step - loss: 25.6096 - mean_absolute_error: 3.4995
# processing fold # 1
# Epoch 1/2
# 303/303 [==============================] - 0s 2ms/step - loss: 218.3267 - mean_absolute_error: 11.2182
# Epoch 2/2
# 303/303 [==============================] - 0s 778us/step - loss: 28.6029 - mean_absolute_error: 3.5317
# processing fold # 2
# Epoch 1/2
# 303/303 [==============================] - 0s 2ms/step - loss: 202.0557 - mean_absolute_error: 10.3172
# Epoch 2/2
# 303/303 [==============================] - 0s 789us/step - loss: 30.3846 - mean_absolute_error: 3.6661
# processing fold # 3
# Epoch 1/2
# 303/303 [==============================] - 1s 2ms/step - loss: 195.8672 - mean_absolute_error: 10.7251
# Epoch 2/2
# ...

# %%
# Print out the average validation score
np.mean(all_scores)
# Out:
# 3.46576466654787

# %% [markdown]
# ## K-Fold Validation by saing validation logs at each fold

# %%
num_epochs = 500
all_mae_histories = []

for i in range(k):
    print('processing fold #', i)
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]
    
    partial_train_data = np.concatenate( [train_data[:i * num_val_samples],
                                          train_data[(i + 1) * num_val_samples:]], axis=0)
    
    partial_train_targets = np.concatenate( [train_targets[:i * num_val_samples],
                                             train_targets[(i + 1) * num_val_samples:]], axis=0)
    
    model = build_model()
    
    history = model.fit(partial_train_data, partial_train_targets,
                        validation_data=(val_data, val_targets),
                        epochs=num_epochs, batch_size=1, verbose=1)

    mae_history = history.history['val_mean_absolute_error']
    
    all_mae_histories.append(mae_history)
# Out:
# processing fold # 0
# Train on 303 samples, validate on 101 samples
# Epoch 1/500
# 303/303 [==============================] - 1s 2ms/step - loss: 210.0457 - mean_absolute_error: 10.9495 - val_loss: 33.6128 - val_mean_absolute_error: 3.6724
# Epoch 2/500
# 303/303 [==============================] - 0s 926us/step - loss: 31.1801 - mean_absolute_error: 3.8069 - val_loss: 23.7647 - val_mean_absolute_error: 2.9254
# Epoch 3/500
# 303/303 [==============================] - 0s 1ms/step - loss: 23.4817 - mean_absolute_error: 3.2912 - val_loss: 17.4004 - val_mean_absolute_error: 2.6308
# Epoch 4/500
# 303/303 [==============================] - 0s 1ms/step - loss: 19.4239 - mean_absolute_error: 2.9402 - val_loss: 15.5099 - val_mean_absolute_error: 2.4718
# Epoch 5/500
# 303/303 [==============================] - 0s 983us/step - loss: 16.9839 - mean_absolute_error: 2.7294 - val_loss: 15.6513 - val_mean_absolute_error: 2.6245
# Epoch 6/500
# ...

# %%
average_mae_history = [
    np.mean([x[i] for x in all_mae_histories]) for i in range(num_epochs)]

# %% [markdown]
# Below we plot the validation scores of the sucessive k-fold groups
# It's difficult to see on the plots but
#     * Omit the first 10 datapoints which are on a different scale than the rest of the curve
#     * Replace each point with an exponential moving average of the previous points to obtain a smooth curve

# %%
plt.plot(range(1, len(average_mae_history) + 1), average_mae_history)
plt.xlabel('Epochs')
plt.ylabel('Validation MAE')

plt.title('Validation MAE before exponential smoothing')
plt.show()

# %%
def smooth_curve(points, factor=0.9):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

smooth_mae_history = smooth_curve(average_mae_history[10:])
plt.plot(range(1, len(smooth_mae_history) + 1), smooth_mae_history)
plt.xlabel('Epochs')
plt.ylabel('Validation MAE')
plt.title('Exponentially SMooth Validation MAE')
plt.show()

# %% [markdown]
# # Training the Final Model

# %%
model = build_model()
model.fit(train_data, train_targets,
         epochs = 80, batch_size = 16, verbose = 1)
test_mse_score, test_mae_score = model.evaluate(test_data, test_targets)
# Out:
# Epoch 1/80
# 404/404 [==============================] - 0s 964us/step - loss: 505.5801 - mean_absolute_error: 20.4985
# Epoch 2/80
# 404/404 [==============================] - 0s 69us/step - loss: 334.6998 - mean_absolute_error: 16.0053
# Epoch 3/80
# 404/404 [==============================] - 0s 68us/step - loss: 167.3951 - mean_absolute_error: 10.4047
# Epoch 4/80
# 404/404 [==============================] - 0s 64us/step - loss: 82.1656 - mean_absolute_error: 6.8500
# Epoch 5/80
# 404/404 [==============================] - 0s 67us/step - loss: 52.3341 - mean_absolute_error: 5.2527
# Epoch 6/80
# 404/404 [==============================] - 0s 69us/step - loss: 34.5128 - mean_absolute_error: 4.1258
# Epoch 7/80
# 404/404 [==============================] - 0s 64us/step - loss: 26.0512 - mean_absolute_error: 3.5228
# Epoch 8/80
# 404/404 [==============================] - 0s 69us/step - loss: 21.8762 - mean_absolute_error: 3.2048
# Epoch 9/80
# ...

# %% [markdown]
# It looks like the model is off by $2722

# %%
test_mae_score
# Out:
# 2.721606909060011
